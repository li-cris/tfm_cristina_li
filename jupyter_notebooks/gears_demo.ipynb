# %% [markdown]
# # GEARS demo

# %%
import itertools
import os

import numpy as np
import pandas as pd
import torch
from anndata import AnnData
from scipy.sparse import csr_matrix
from scipy.stats import pearsonr
import random

# GEARS imports
from gears import GEARS, PertData

# Own imports
from data_utils.metrics import MMDLoss, compute_kld

# %%
DATA_DIR_PATH = "data"
MODELS_DIR_PATH = "models"
RESULTS_DIR_PATH = "results"

PREDICT_DOUBLE = True

# Set to True if training only has single perturbations (train + val) and double perturbations are on test.
SINGLE_TRAIN_ONLY = True

# %% [markdown]
# ### Code and functions

# %%
def set_seeds(seed: int) -> None:
    """Set random seeds for reproducibility."""
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

# %%
def train(
    pert_data: PertData, dataset_name: str, model_savedir: str,
    split: str, seed: int, hidden_size: int, device: str, epochs: int = 20
) -> str:
    """Set up, train, and save GEARS model."""
    print("Training GEARS model.")
    gears_model = GEARS(pert_data=pert_data, device=device)
    gears_model.model_initialize(hidden_size=hidden_size)
    gears_model.train(epochs=epochs)
    model_name = (
        f"gears_{dataset_name}_split_{split}_seed_{str(seed)}_hidden_size_{str(hidden_size)}"
    )
    gears_model.save_model(path=os.path.join(model_savedir, model_name))
    return model_name

# %%
def predict(pert_data: PertData,
            device: str, model_name: str,
            model_savedir: str, results_savedir: str) -> None:
    """Predict with GEARS model."""
    # Load the model.
    print("Loading GEARS model.")
    gears_model = GEARS(pert_data=pert_data, device=device)
    gears_model.load_pretrained(path=os.path.join(model_savedir, model_name))

    # Get all single perturbations.
    single_perturbations = set(
        [
            c.strip("+ctrl")
            for c in pert_data.adata.obs["condition"]
            if ("ctrl+" in c) or ("+ctrl" in c)
        ]
    )
    print(f"Number of single perturbations: {len(single_perturbations)}")

    # Get all double perturbations.
    double_perturbations = set(
        [c for c in pert_data.adata.obs["condition"] if "ctrl" not in c]
    )
    print(f"Number of double perturbations: {len(double_perturbations)}")

    # Generate all possible double perturbations (combos).
    combo_perturbations = []
    for g1 in single_perturbations:
        for g2 in single_perturbations:
            if g1 == g2:
                continue
            combo_perturbations.append(sorted([g1, g2]))
    combo_perturbations.sort()
    combo_perturbations = list(k for k, _ in itertools.groupby(combo_perturbations))
    print(f"Number of combo perturbations: {len(combo_perturbations)}")

    # Get the names of all measured genes as comma-separated list.
    var_names_str = ",".join(map(str, list(pert_data.adata.var_names)))

    if PREDICT_DOUBLE:
        # Predict all double perturbations.
        double_results_file_path = os.path.join(
            results_savedir, f"{model_name}_double.csv"
        )
        with open(file=double_results_file_path, mode="w") as f:
            print(f"double,{var_names_str}", file=f)
            for i, d in enumerate(double_perturbations):
                print(f"Predicting double {i + 1}/{len(double_perturbations)}: {d}")
                prediction = gears_model.predict(pert_list=[d.split("+")])
                double = next(iter(prediction.keys()))
                expressions = prediction[double]
                expressions_str = ",".join(map(str, expressions))
                print(f"{double},{expressions_str}", file=f)

# %% [markdown]
# Key points in evaluation:
# - The original PertData used for training is reloaded, but only double perturbations are maintained as ground truth to compare against predictions.
# - Randomly selected control samples based on current seed.
# - Another randomly selected set of control samples.
# - Instead of using the whole gene expression profiles (GEP), Differential Gene Expresion is used. </br>
#
# The first set of control samples is substracted from True GEPs and Predicted GEPs for each double perturbation evaluation. </br>
# For control samples, the second set of samples is substracted to ensure that baseline values are not constant, since that generates problems during computation. </br>

# %%
def evaluate_double(adata: AnnData, model_name: str, results_savedir: str,
                    pool_size: int = 250, seed: int = 42, top_deg: int = 20) -> None:
    """Evaluate the predicted GEPs of double perturbations."""
    # Load predicted GEPs.
    df = pd.read_csv(
        filepath_or_buffer=os.path.join(results_savedir, f"{model_name}_double.csv")
    )

    # Make results file path.
    results_file_path = os.path.join(
        results_savedir, f"{model_name}_double_metrics.csv"
    )

    with open(file=results_file_path, mode="w") as f:
        print(
            f"double,mmd_true_vs_ctrl,mmd_true_vs_pred,mse_true_vs_ctrl,mse_true_vs_pred,kld_true_vs_ctrl,kld_true_vs_pred,pearsonTop{top_deg}_true_vs_ctrl,pearson_pval_true_vs_ctrl,pearsonTop{top_deg}_true_vs_pred,pearson_pval_true_vs_pred",
            file=f,
        )

        for i, double in enumerate(df["double"]):
            # Get the predicted GEP for the current double perturbation.
            pred_geps = df.loc[df["double"] == double]
            pred_geps = pred_geps.iloc[0, 1:].tolist()
            pred_geps = np.array([pred_geps])

            # Get all the true GEPs with the current double perturbation.
            double = double.replace("_", "+")
            print(f"Evaluating double {i + 1}/{len(df['double'])}: {double}")
            true_geps = adata[adata.obs["condition"] == double]

            # Limiting n
            if true_geps.n_obs>pool_size:
                n = pool_size
                random_indices = np.random.choice(true_geps.n_obs, size=n, replace=False)
                true_geps = true_geps[random_indices, :]  
            else:
                # If less than pool size, randomly sample from all true_geps to avoid error in MMD computation
                n = true_geps.n_obs

            set_seeds(seed)

            # Obtaining random sample of ctrl GEP
            all_ctrl_geps = adata[adata.obs["condition"] == "ctrl"]
            random_indices = np.random.choice(
                all_ctrl_geps.n_obs, size=n, replace=False
            )
            ctrl_geps = all_ctrl_geps[random_indices, :]
            pred_geps = csr_matrix(np.tile(pred_geps, reps=(n, 1)))

            # Another random ctrl_gep
            random_indices_2 = np.random.choice(
                all_ctrl_geps.n_obs, size=n, replace=False
            )
            ctrl_geps_2 = all_ctrl_geps[random_indices_2, :]

            # Tensor conversion and differential expression
            ctrl_geps_tensor = torch.tensor(ctrl_geps.X.toarray())
            ctrl_ctrl_geps_tensor = torch.tensor(ctrl_geps_2.X.toarray()) - ctrl_geps_tensor
            true_ctrl_geps_tensor = torch.tensor(true_geps.X.toarray()) - ctrl_geps_tensor
            pred_ctrl_geps_tensor = torch.tensor(pred_geps.toarray()) - ctrl_geps_tensor

            # MMD setup.
            mmd_sigma = 200.0
            kernel_num = 10
            mmd_loss = MMDLoss(fix_sigma=mmd_sigma, kernel_num=kernel_num)

            # Compute MMD 
            mmd_true_vs_ctrl = mmd_loss.forward(
                            source=ctrl_ctrl_geps_tensor, target=true_ctrl_geps_tensor
                        )

            mmd_true_vs_pred = mmd_loss.forward(
                source=pred_ctrl_geps_tensor, target=true_ctrl_geps_tensor
            )

            # Compute MSE
            mse_true_vs_ctrl = torch.mean(
                (true_ctrl_geps_tensor - ctrl_ctrl_geps_tensor) ** 2
            ).item()
            mse_true_vs_pred = torch.mean(
                (true_ctrl_geps_tensor - pred_ctrl_geps_tensor) ** 2
            ).item()

            # Compute KLD
            kld_true_vs_ctrl = compute_kld(true_ctrl_geps_tensor, ctrl_ctrl_geps_tensor)
            kld_true_vs_pred = compute_kld(true_ctrl_geps_tensor, pred_ctrl_geps_tensor)

            # Compute Pearson for top DEG
            true_deg = true_ctrl_geps_tensor.mean(dim=0).cpu().detach().numpy()
            ctrl_ctrl_deg = ctrl_ctrl_geps_tensor.mean(dim=0).cpu().detach().numpy()
            pred_deg = pred_ctrl_geps_tensor.mean(dim=0).cpu().detach().numpy()
            topdeg_idx = np.argsort(abs(true_deg))[-top_deg:]

            pearson_true_vs_ctrl = pearsonr(true_deg[topdeg_idx], ctrl_ctrl_deg[topdeg_idx])
            pearson_true_vs_pred = pearsonr(true_deg[topdeg_idx], pred_deg[topdeg_idx])


            print(f"MMD (true vs. control):   {mmd_true_vs_ctrl:10.6f}")
            print(f"MMD (true vs. predicted): {mmd_true_vs_pred:10.6f}")
            print(f"MSE (true vs. control):   {mse_true_vs_ctrl:10.6f}")
            print(f"MSE (true vs. predicted): {mse_true_vs_pred:10.6f}")
            print(f"KLD (true vs. control):   {kld_true_vs_ctrl:10.6f}")
            print(f"KLD (true vs. predicted): {kld_true_vs_pred:10.6f}")
            print(f"Pearson Top {top_deg} DEG (true vs. control): {pearson_true_vs_ctrl.statistic:.6f} | p-value: {pearson_true_vs_ctrl.pvalue:.6f}")
            print(f"Pearson Top {top_deg} DEG (true vs. predicted): {pearson_true_vs_pred.statistic:.6f} | p-value: {pearson_true_vs_pred.pvalue:.6f}")

            print(
                f"{double},{mmd_true_vs_ctrl},{mmd_true_vs_pred},{mse_true_vs_ctrl},{mse_true_vs_pred},{kld_true_vs_ctrl},{kld_true_vs_pred},{pearson_true_vs_ctrl.statistic},{pearson_true_vs_ctrl.pvalue},{pearson_true_vs_pred.statistic},{pearson_true_vs_pred.pvalue}",
                file=f,
            )

# %% [markdown]
# ### GEARS

# %% [markdown]
# The full script to run GEARS from command line also allows to change some hyperparameters. </br>
#
# Data is loaded from the data path where the PertData object is stored. </br>
# 'Raw' data as .h5ad file has to be previously converted through GEARS' own data handler for the training to work. </br>
#
# In this project, all models have been trained with only single perturbation and control data. GEARS' data handler is already built to be able to withold the fraction of double perturbation required.
#  </br>
#
#  Calculations are made for:
# - MSE (overall prediction)
# - MMD (distrubution)
# - Pearson (prediction of direction of change) </br>
#
# Pearson is calculated from the mean expression of all taken samples for each group (perturbation prediction, perturbation truth and control). </br>
# For Pearson, using the whole vector of expression values will result in P close to 1 in most cases, as gene expression vector are often filled with genes that have 0 expression. Instead, the Top X Differentially Expressed Genes can be chosen, which are chosen based on the True perturbation samples. </br>
# In this Notebook, only 1 iteration of the training is done, but the script is written to allow more iterations with different seeds.

# %%
split = 'simulation' # Divides into Train/Val and Test
seed = 42
hidden_size = 64
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
project_name = 'demo_test'
dataset_name = 'norman_reduced'
pool_size = 50
num_runs = 1
epochs = 3
top_deg = 20

# %%
# Create directories.
os.makedirs(name=DATA_DIR_PATH, exist_ok=True)
os.makedirs(name=MODELS_DIR_PATH, exist_ok=True)
os.makedirs(name=RESULTS_DIR_PATH, exist_ok=True)

# Create directory for custom project name in MODELS_DIR_PATH and RESULTS_DIR_PATH.
model_savedir = os.path.join(MODELS_DIR_PATH, project_name)
results_savedir = os.path.join(RESULTS_DIR_PATH, project_name)
os.makedirs(name=model_savedir, exist_ok=True)
os.makedirs(name=results_savedir, exist_ok=True)

# %%
# Load "norman" data.
data_name = dataset_name
print(f"Loading '{data_name}' data.")
pertdata = PertData(DATA_DIR_PATH)
pertdata.load(data_path=os.path.join(DATA_DIR_PATH, data_name))
# Out:
# Found local copy...
# Loading 'norman_reduced' data.
# Found local copy...
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['LYL1+IER5L' 'IER5L+ctrl' 'KIAA1804+ctrl' 'ctrl+IER5L']
# Local copy of pyg dataset is detected. Loading...
# Done!

# %%
# Running train, predict, evaluate for multiple runs.
current_run = 0
current_seed = seed + current_run
print(f"Current run: {current_run + 1}/{num_runs}, Seed: {current_seed}")

# Split data and get dataloaders.
# This split of train test sizes keeps singles in training and validation and doubles in testing
print("Preparing data split.")
if SINGLE_TRAIN_ONLY:
    # If training only has single perturbations, we need to set the train_gene_set_size
    # to 1.0 (keep all single pertubation genes) and combo_seen2_train_frac to 0.0 (don't keep any double perturbation genes)
    print("Keeping only single perturbation samples in training.")
    pertdata.prepare_split(
        split=split,
        seed=current_seed,
        train_gene_set_size=1.0,
        combo_seen2_train_frac=0.0
    )
else:
    pertdata.prepare_split(split=split, seed=current_seed)
pertdata.get_dataloader(batch_size=32)
# Out:
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:130
# unseen_single:0
# Done!
# Creating dataloaders....
# Done!
# Current run: 1/1, Seed: 42
# Preparing data split.
# Keeping only single perturbation samples in training.
# here1

# %%
# Train.
model_name = train(
    pert_data=pertdata,
    dataset_name=dataset_name,
    model_savedir=model_savedir,
    split=split,
    seed=current_seed,
    hidden_size=hidden_size,
    device=device,
    epochs=epochs
)
# Out:
# Training GEARS model.
# Found local copy...
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.6946
# Epoch 1 Step 51 Train Loss: 0.6973
# Epoch 1 Step 101 Train Loss: 0.6872
# Epoch 1: Train Overall MSE: 0.0068 Validation Overall MSE: 0.0049.
# Train Top 20 DE MSE: 0.1392 Validation Top 20 DE MSE: 0.2115.
# Epoch 2 Step 1 Train Loss: 0.5751
# Epoch 2 Step 51 Train Loss: 0.7926
# Epoch 2 Step 101 Train Loss: 0.7243
# Epoch 2: Train Overall MSE: 0.0058 Validation Overall MSE: 0.0053.
# Train Top 20 DE MSE: 0.1113 Validation Top 20 DE MSE: 0.1954.
# Epoch 3 Step 1 Train Loss: 0.6627
# Epoch 3 Step 51 Train Loss: 0.7356
# Epoch 3 Step 101 Train Loss: 0.7539
# Epoch 3: Train Overall MSE: 0.0055 Validation Overall MSE: 0.0053.
# Train Top 20 DE MSE: 0.0978 Validation Top 20 DE MSE: 0.2014.
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.2586
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: nan
# test_combo_seen0_pearson: nan
# test_combo_seen0_mse_de: nan
# test_combo_seen0_pearson_de: nan
# test_combo_seen1_mse: nan
# test_combo_seen1_pearson: nan
# test_combo_seen1_mse_de: nan
# test_combo_seen1_pearson_de: nan
# test_combo_seen2_mse: 0.007535134
# test_combo_seen2_pearson: 0.9797873976468316
# test_combo_seen2_mse_de: 0.25863224
# test_combo_seen2_pearson_de: 0.8997482498986493
# test_unseen_single_mse: nan
# test_unseen_single_pearson: nan
# test_unseen_single_mse_de: nan
# test_unseen_single_pearson_de: nan
# test_combo_seen0_pearson_delta: nan
# test_combo_seen0_frac_opposite_direction_top20_non_dropout: nan
# test_combo_seen0_frac_sigma_below_1_non_dropout: nan
# test_combo_seen0_mse_top20_de_non_dropout: nan
# test_combo_seen1_pearson_delta: nan
# test_combo_seen1_frac_opposite_direction_top20_non_dropout: nan
# test_combo_seen1_frac_sigma_below_1_non_dropout: nan
# test_combo_seen1_mse_top20_de_non_dropout: nan
# test_combo_seen2_pearson_delta: 0.40338706236802285
# test_combo_seen2_frac_opposite_direction_top20_non_dropout: 0.135
# test_combo_seen2_frac_sigma_below_1_non_dropout: 0.8196153846153846
# test_combo_seen2_mse_top20_de_non_dropout: 0.25875404
# test_unseen_single_pearson_delta: nan
# test_unseen_single_frac_opposite_direction_top20_non_dropout: nan
# test_unseen_single_frac_sigma_below_1_non_dropout: nan
# test_unseen_single_mse_top20_de_non_dropout: nan
# Done!

# %%
# Predict.
predict(pert_data=pertdata, device=device, model_name=model_name,
        model_savedir=model_savedir, results_savedir=results_savedir)
# Out:
# Loading GEARS model.
# Number of single perturbations: 103
# Number of double perturbations: 130
# Number of combo perturbations: 5253
# Predicting double 1/130: C3orf72+FOXL2
# Predicting double 2/130: ZBTB10+PTPN12
# Predicting double 3/130: SGK1+S1PR2
# Predicting double 4/130: RHOXF2+ZBTB25
# Predicting double 5/130: KLF1+TGFBR2
# Predicting double 6/130: CEBPE+SPI1
# Predicting double 7/130: DUSP9+PRTG
# Predicting double 8/130: ETS2+MAP7D1
# Predicting double 9/130: CDKN1C+CDKN1B
# Predicting double 10/130: MAP2K3+MAP2K6
# Predicting double 11/130: SAMD1+UBASH3B
# Predicting double 12/130: CEBPE+CEBPB
# Predicting double 13/130: FOSB+CEBPB
# Predicting double 14/130: DUSP9+SNAI1
# Predicting double 15/130: CBL+CNN1
# Predicting double 16/130: FOXA3+FOXF1
# Predicting double 17/130: CBL+UBASH3B
# Predicting double 18/130: ZC3HAV1+CEBPE
# Predicting double 19/130: AHR+KLF1
# Predicting double 20/130: BCL2L11+BAK1
# Predicting double 21/130: FEV+ISL2
# Predicting double 22/130: JUN+CEBPB
# Predicting double 23/130: LYL1+CEBPB
# Predicting double 24/130: FOXA1+FOXL2
# Predicting double 25/130: FOSB+CEBPE
# Predicting double 26/130: ETS2+CEBPE
# Predicting double 27/130: CBL+PTPN9
# Predicting double 28/130: UBASH3B+PTPN12
# Predicting double 29/130: FOXL2+HOXB9
# Predicting double 30/130: TMSB4X+BAK1
# Predicting double 31/130: MAPK1+IKZF3
# Predicting double 32/130: BPGM+SAMD1
# Predicting double 33/130: CEBPB+CEBPA
# Predicting double 34/130: KIF18B+KIF2C
# Predicting double 35/130: FOXL2+MEIS1
# Predicting double 36/130: MAPK1+TGFBR2
# Predicting double 37/130: SNAI1+DLX2
# Predicting double 38/130: ETS2+IGDCC3
# Predicting double 39/130: KLF1+CLDN6
# Predicting double 40/130: PRDM1+CBFA2T3
# Predicting double 41/130: FOXA1+HOXB9
# Predicting double 42/130: ZNF318+FOXL2
# Predicting double 43/130: UBASH3B+PTPN9
# Predicting double 44/130: PTPN12+UBASH3A
# Predicting double 45/130: CEBPE+PTPN12
# Predicting double 46/130: UBASH3B+ZBTB25
# Predicting double 47/130: FOXA3+HOXB9
# Predicting double 48/130: PTPN12+OSR2
# Predicting double 49/130: FOXA3+FOXL2
# Predicting double 50/130: FEV+MAP7D1
# Predicting double 51/130: FOSB+UBASH3B
# Predicting double 52/130: IRF1+SET
# Predicting double 53/130: MAP2K6+SPI1
# Predicting double 54/130: UBASH3B+UBASH3A
# Predicting double 55/130: SAMD1+ZBTB1
# Predicting double 56/130: POU3F2+CBFA2T3
# Predicting double 57/130: AHR+FEV
# Predicting double 58/130: MAPK1+PRTG
# Predicting double 59/130: KLF1+MAP2K6
# Predicting double 60/130: RHOXF2+SET
# Predicting double 61/130: PTPN12+PTPN9
# Predicting double 62/130: CNN1+UBASH3A
# Predicting double 63/130: KLF1+CEBPA
# Predicting double 64/130: ETS2+MAPK1
# Predicting double 65/130: FEV+CBFA2T3
# Predicting double 66/130: SGK1+TBX2
# Predicting double 67/130: SAMD1+TGFBR2
# Predicting double 68/130: MAP2K6+ELMSAN1
# Predicting double 69/130: SNAI1+UBASH3B
# Predicting double 70/130: PTPN12+ZBTB25
# Predicting double 71/130: CEBPE+KLF1
# Predicting double 72/130: TGFBR2+ETS2
# Predicting double 73/130: FOSB+IKZF3
# Predicting double 74/130: FOXA3+FOXA1
# Predicting double 75/130: ETS2+PRTG
# Predicting double 76/130: SET+KLF1
# Predicting double 77/130: ZC3HAV1+HOXC13
# Predicting double 78/130: TBX3+TBX2
# Predicting double 79/130: KLF1+COL2A1
# Predicting double 80/130: CBL+TGFBR2
# Predicting double 81/130: TGFBR2+IGDCC3
# Predicting double 82/130: MAP2K3+IKZF3
# Predicting double 83/130: SET+CEBPE
# Predicting double 84/130: ZBTB10+DLX2
# Predicting double 85/130: DUSP9+ETS2
# Predicting double 86/130: CEBPB+MAPK1
# Predicting double 87/130: POU3F2+FOXL2
# Predicting double 88/130: CNN1+MAPK1
# Predicting double 89/130: CEBPE+CEBPA
# Predicting double 90/130: UBASH3B+CNN1
# Predicting double 91/130: ETS2+CNN1
# Predicting double 92/130: DUSP9+IGDCC3
# Predicting double 93/130: PTPN12+SNAI1
# Predicting double 94/130: FOXA1+FOXF1
# Predicting double 95/130: CEBPE+CNN1
# Predicting double 96/130: TGFBR2+PRTG
# Predicting double 97/130: FOXF1+HOXB9
# Predicting double 98/130: CEBPE+RUNX1T1
# Predicting double 99/130: CBL+PTPN12
# Predicting double 100/130: FOXF1+FOXL2
# Predicting double 101/130: KLF1+FOXA1
# Predicting double 102/130: MAP2K6+IKZF3
# Predicting double 103/130: CEBPB+OSR2
# Predicting double 104/130: CDKN1C+CDKN1A
# Predicting double 105/130: JUN+CEBPA
# Predicting double 106/130: IGDCC3+MAPK1
# Predicting double 107/130: KLF1+BAK1
# Predicting double 108/130: ZBTB10+ELMSAN1
# Predicting double 109/130: FOSB+PTPN12
# Predicting double 110/130: ZBTB10+SNAI1
# Predicting double 111/130: SAMD1+PTPN12
# Predicting double 112/130: PLK4+STIL
# Predicting double 113/130: TGFBR2+C19orf26
# Predicting double 114/130: BPGM+ZBTB1
# Predicting double 115/130: BCL2L11+TGFBR2
# Predicting double 116/130: SGK1+TBX3
# Predicting double 117/130: FOSB+OSR2
# Predicting double 118/130: UBASH3B+OSR2
# Predicting double 119/130: CBL+UBASH3A
# Predicting double 120/130: DUSP9+MAPK1
# Predicting double 121/130: IGDCC3+PRTG
# Predicting double 122/130: MAP2K3+ELMSAN1
# Predicting double 123/130: LHX1+ELMSAN1
# Predicting double 124/130: ZC3HAV1+CEBPA
# Predicting double 125/130: ETS2+IKZF3
# Predicting double 126/130: CEBPB+PTPN12
# Predicting double 127/130: IGDCC3+ZBTB25
# Predicting double 128/130: MAP2K3+SLC38A2
# Predicting double 129/130: CDKN1B+CDKN1A
# Predicting double 130/130: DUSP9+KLF1

# %%
# Evaluate.
pertdata = PertData(DATA_DIR_PATH)
pertdata.load(data_path=os.path.join(DATA_DIR_PATH, data_name))
evaluate_double(adata=pertdata.adata, model_name=model_name,
                results_savedir=results_savedir, pool_size=pool_size,
                seed=current_seed, top_deg=top_deg)
# Out:
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['LYL1+IER5L' 'IER5L+ctrl' 'KIAA1804+ctrl' 'ctrl+IER5L']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Evaluating double 1/130: C3orf72+FOXL2
# MMD (true vs. control):     0.339430
# MMD (true vs. predicted):   0.623679
# MSE (true vs. control):     0.086623
# MSE (true vs. predicted):   0.053890
# KLD (true vs. control):     0.002077
# KLD (true vs. predicted):   0.001739
# Pearson Top 20 DEG (true vs. control): -0.066646 | p-value: 0.780115
# Pearson Top 20 DEG (true vs. predicted): 0.750948 | p-value: 0.000136
# Evaluating double 2/130: ZBTB10+PTPN12
# MMD (true vs. control):     0.376876
# MMD (true vs. predicted):   0.703073
# MSE (true vs. control):     0.091089
# MSE (true vs. predicted):   0.058669
# KLD (true vs. control):     0.003361
# KLD (true vs. predicted):   0.003322
# Pearson Top 20 DEG (true vs. control): -0.133943 | p-value: 0.573443
# Pearson Top 20 DEG (true vs. predicted): 0.854320 | p-value: 0.000002
# Evaluating double 3/130: SGK1+S1PR2
# MMD (true vs. control):     0.385643
# MMD (true vs. predicted):   0.638535
# MSE (true vs. control):     0.083990
# MSE (true vs. predicted):   0.050543
# KLD (true vs. control):     0.004669
# KLD (true vs. predicted):   0.003529
# Pearson Top 20 DEG (true vs. control): 0.367951 | p-value: 0.110454
# Pearson Top 20 DEG (true vs. predicted): 0.710611 | p-value: 0.000446
# Evaluating double 4/130: RHOXF2+ZBTB25
# MMD (true vs. control):     0.410998
# MMD (true vs. predicted):   0.645421
# MSE (true vs. control):     0.085957
# MSE (true vs. predicted):   0.050997
# KLD (true vs. control):     0.006405
# KLD (true vs. predicted):   0.003855
# Pearson Top 20 DEG (true vs. control): 0.215142 | p-value: 0.362335
# Pearson Top 20 DEG (true vs. predicted): 0.920853 | p-value: 0.000000
# Evaluating double 5/130: KLF1+TGFBR2
# MMD (true vs. control):     0.332317
# MMD (true vs. predicted):   0.551943
# MSE (true vs. control):     0.067557
# MSE (true vs. predicted):   0.036747
# KLD (true vs. control):     0.003217
# KLD (true vs. predicted):   0.003444
# Pearson Top 20 DEG (true vs. control): -0.250833 | p-value: 0.286107
# Pearson Top 20 DEG (true vs. predicted): 0.771662 | p-value: 0.000068
# Evaluating double 6/130: CEBPE+SPI1
# MMD (true vs. control):     0.571234
# MMD (true vs. predicted):   0.944217
# MSE (true vs. control):     0.122430
# MSE (true vs. predicted):   0.083044
# KLD (true vs. control):     0.015821
# KLD (true vs. predicted):   0.008039
# Pearson Top 20 DEG (true vs. control): -0.289555 | p-value: 0.215610
# Pearson Top 20 DEG (true vs. predicted): 0.968568 | p-value: 0.000000
# Evaluating double 7/130: DUSP9+PRTG
# MMD (true vs. control):     0.433451
# MMD (true vs. predicted):   0.723166
# MSE (true vs. control):     0.086555
# MSE (true vs. predicted):   0.053629
# KLD (true vs. control):     0.009091
# KLD (true vs. predicted):   0.005240
# Pearson Top 20 DEG (true vs. control): 0.215012 | p-value: 0.362633
# Pearson Top 20 DEG (true vs. predicted): 0.956180 | p-value: 0.000000
# Evaluating double 8/130: ETS2+MAP7D1
# MMD (true vs. control):     0.338769
# MMD (true vs. predicted):   0.582732
# MSE (true vs. control):     0.076178
# MSE (true vs. predicted):   0.044380
# KLD (true vs. control):     0.002651
# KLD (true vs. predicted):   0.003010
# Pearson Top 20 DEG (true vs. control): 0.000677 | p-value: 0.997739
# Pearson Top 20 DEG (true vs. predicted): 0.487718 | p-value: 0.029151
# Evaluating double 9/130: CDKN1C+CDKN1B
# MMD (true vs. control):     0.345884
# MMD (true vs. predicted):   0.625441
# MSE (true vs. control):     0.075315
# MSE (true vs. predicted):   0.044817
# KLD (true vs. control):     0.002445
# KLD (true vs. predicted):   0.003204
# Pearson Top 20 DEG (true vs. control): -0.088515 | p-value: 0.710570
# Pearson Top 20 DEG (true vs. predicted): 0.885282 | p-value: 0.000000
# Evaluating double 10/130: MAP2K3+MAP2K6
# MMD (true vs. control):     0.287046
# MMD (true vs. predicted):   0.566562
# MSE (true vs. control):     0.064610
# MSE (true vs. predicted):   0.037307
# KLD (true vs. control):     0.001015
# KLD (true vs. predicted):   0.003236
# Pearson Top 20 DEG (true vs. control): -0.148873 | p-value: 0.531040
# Pearson Top 20 DEG (true vs. predicted): 0.850880 | p-value: 0.000002
# Evaluating double 11/130: SAMD1+UBASH3B
# MMD (true vs. control):     0.362588
# MMD (true vs. predicted):   0.608635
# MSE (true vs. control):     0.085921
# MSE (true vs. predicted):   0.051199
# KLD (true vs. control):     0.003960
# KLD (true vs. predicted):   0.002394
# Pearson Top 20 DEG (true vs. control): 0.410512 | p-value: 0.072198
# Pearson Top 20 DEG (true vs. predicted): 0.969151 | p-value: 0.000000
# Evaluating double 12/130: CEBPE+CEBPB
# MMD (true vs. control):     0.454963
# MMD (true vs. predicted):   0.896205
# MSE (true vs. control):     0.113767
# MSE (true vs. predicted):   0.080591
# KLD (true vs. control):     0.007906
# KLD (true vs. predicted):   0.006274
# Pearson Top 20 DEG (true vs. control): -0.075064 | p-value: 0.753123
# Pearson Top 20 DEG (true vs. predicted): 0.942201 | p-value: 0.000000
# Evaluating double 13/130: FOSB+CEBPB
# MMD (true vs. control):     0.468658
# MMD (true vs. predicted):   0.827261
# MSE (true vs. control):     0.108983
# MSE (true vs. predicted):   0.074606
# KLD (true vs. control):     0.008950
# KLD (true vs. predicted):   0.006936
# Pearson Top 20 DEG (true vs. control): 0.121775 | p-value: 0.609043
# Pearson Top 20 DEG (true vs. predicted): 0.945430 | p-value: 0.000000
# Evaluating double 14/130: DUSP9+SNAI1
# MMD (true vs. control):     0.466867
# MMD (true vs. predicted):   0.789380
# MSE (true vs. control):     0.101124
# MSE (true vs. predicted):   0.066425
# KLD (true vs. control):     0.006457
# KLD (true vs. predicted):   0.005735
# Pearson Top 20 DEG (true vs. control): 0.217161 | p-value: 0.357739
# Pearson Top 20 DEG (true vs. predicted): 0.768576 | p-value: 0.000075
# Evaluating double 15/130: CBL+CNN1
# MMD (true vs. control):     0.429486
# MMD (true vs. predicted):   0.731612
# MSE (true vs. control):     0.087936
# MSE (true vs. predicted):   0.054968
# KLD (true vs. control):     0.009509
# KLD (true vs. predicted):   0.006223
# Pearson Top 20 DEG (true vs. control): 0.217200 | p-value: 0.357650
# Pearson Top 20 DEG (true vs. predicted): 0.909989 | p-value: 0.000000
# Evaluating double 16/130: FOXA3+FOXF1
# MMD (true vs. control):     0.359708
# MMD (true vs. predicted):   0.630681
# MSE (true vs. control):     0.090476
# MSE (true vs. predicted):   0.056745
# KLD (true vs. control):     0.002944
# KLD (true vs. predicted):   0.002565
# Pearson Top 20 DEG (true vs. control): 0.002041 | p-value: 0.993186
# Pearson Top 20 DEG (true vs. predicted): 0.791316 | p-value: 0.000032
# Evaluating double 17/130: CBL+UBASH3B
# MMD (true vs. control):     0.426417
# MMD (true vs. predicted):   0.643125
# MSE (true vs. control):     0.085764
# MSE (true vs. predicted):   0.051062
# KLD (true vs. control):     0.007756
# KLD (true vs. predicted):   0.004333
# Pearson Top 20 DEG (true vs. control): 0.120179 | p-value: 0.613778
# Pearson Top 20 DEG (true vs. predicted): 0.957005 | p-value: 0.000000
# Evaluating double 18/130: ZC3HAV1+CEBPE
# MMD (true vs. control):     0.302524
# MMD (true vs. predicted):   0.480486
# MSE (true vs. control):     0.066692
# MSE (true vs. predicted):   0.034245
# KLD (true vs. control):     0.001508
# KLD (true vs. predicted):   0.001676
# Pearson Top 20 DEG (true vs. control): -0.089680 | p-value: 0.706920
# Pearson Top 20 DEG (true vs. predicted): 0.884162 | p-value: 0.000000
# Evaluating double 19/130: AHR+KLF1
# MMD (true vs. control):     0.330484
# MMD (true vs. predicted):   0.568997
# MSE (true vs. control):     0.070098
# MSE (true vs. predicted):   0.039385
# KLD (true vs. control):     0.002862
# KLD (true vs. predicted):   0.003145
# Pearson Top 20 DEG (true vs. control): -0.198799 | p-value: 0.400770
# Pearson Top 20 DEG (true vs. predicted): 0.689305 | p-value: 0.000774
# Evaluating double 20/130: BCL2L11+BAK1
# MMD (true vs. control):     0.277973
# MMD (true vs. predicted):   0.493363
# MSE (true vs. control):     0.066669
# MSE (true vs. predicted):   0.035944
# KLD (true vs. control):     0.000701
# KLD (true vs. predicted):   0.001788
# Pearson Top 20 DEG (true vs. control): 0.129253 | p-value: 0.587059
# Pearson Top 20 DEG (true vs. predicted): 0.709465 | p-value: 0.000460
# Evaluating double 21/130: FEV+ISL2
# MMD (true vs. control):     0.476782
# MMD (true vs. predicted):   0.809251
# MSE (true vs. control):     0.102119
# MSE (true vs. predicted):   0.067001
# KLD (true vs. control):     0.008212
# KLD (true vs. predicted):   0.006795
# Pearson Top 20 DEG (true vs. control): 0.534750 | p-value: 0.015129
# Pearson Top 20 DEG (true vs. predicted): 0.789992 | p-value: 0.000034
# Evaluating double 22/130: JUN+CEBPB
# MMD (true vs. control):     0.485114
# MMD (true vs. predicted):   0.879664
# MSE (true vs. control):     0.113584
# MSE (true vs. predicted):   0.078229
# KLD (true vs. control):     0.007950
# KLD (true vs. predicted):   0.006315
# Pearson Top 20 DEG (true vs. control): 0.159339 | p-value: 0.502213
# Pearson Top 20 DEG (true vs. predicted): 0.818006 | p-value: 0.000011
# Evaluating double 23/130: LYL1+CEBPB
# MMD (true vs. control):     0.336093
# MMD (true vs. predicted):   0.569663
# MSE (true vs. control):     0.076749
# MSE (true vs. predicted):   0.043907
# KLD (true vs. control):     0.002592
# KLD (true vs. predicted):   0.002505
# Pearson Top 20 DEG (true vs. control): -0.199151 | p-value: 0.399920
# Pearson Top 20 DEG (true vs. predicted): 0.612772 | p-value: 0.004072
# Evaluating double 24/130: FOXA1+FOXL2
# MMD (true vs. control):     0.344474
# MMD (true vs. predicted):   0.633105
# MSE (true vs. control):     0.087043
# MSE (true vs. predicted):   0.056145
# KLD (true vs. control):     0.002469
# KLD (true vs. predicted):   0.002322
# Pearson Top 20 DEG (true vs. control): 0.047072 | p-value: 0.843776
# Pearson Top 20 DEG (true vs. predicted): 0.826517 | p-value: 0.000007
# Evaluating double 25/130: FOSB+CEBPE
# MMD (true vs. control):     0.448564
# MMD (true vs. predicted):   0.840813
# MSE (true vs. control):     0.105544
# MSE (true vs. predicted):   0.072593
# KLD (true vs. control):     0.008106
# KLD (true vs. predicted):   0.006746
# Pearson Top 20 DEG (true vs. control): 0.195618 | p-value: 0.408504
# Pearson Top 20 DEG (true vs. predicted): 0.975557 | p-value: 0.000000
# Evaluating double 26/130: ETS2+CEBPE
# MMD (true vs. control):     0.399154
# MMD (true vs. predicted):   0.720223
# MSE (true vs. control):     0.085038
# MSE (true vs. predicted):   0.052961
# KLD (true vs. control):     0.005202
# KLD (true vs. predicted):   0.005082
# Pearson Top 20 DEG (true vs. control): -0.212847 | p-value: 0.367602
# Pearson Top 20 DEG (true vs. predicted): 0.972945 | p-value: 0.000000
# Evaluating double 27/130: CBL+PTPN9
# MMD (true vs. control):     0.373140
# MMD (true vs. predicted):   0.611224
# MSE (true vs. control):     0.083323
# MSE (true vs. predicted):   0.048791
# KLD (true vs. control):     0.003771
# KLD (true vs. predicted):   0.002516
# Pearson Top 20 DEG (true vs. control): 0.050494 | p-value: 0.832567
# Pearson Top 20 DEG (true vs. predicted): 0.843018 | p-value: 0.000003
# Evaluating double 28/130: UBASH3B+PTPN12
# MMD (true vs. control):     0.351862
# MMD (true vs. predicted):   0.561471
# MSE (true vs. control):     0.076949
# MSE (true vs. predicted):   0.043464
# KLD (true vs. control):     0.003725
# KLD (true vs. predicted):   0.002430
# Pearson Top 20 DEG (true vs. control): 0.491479 | p-value: 0.027750
# Pearson Top 20 DEG (true vs. predicted): 0.972671 | p-value: 0.000000
# Evaluating double 29/130: FOXL2+HOXB9
# MMD (true vs. control):     0.415715
# MMD (true vs. predicted):   0.736176
# MSE (true vs. control):     0.099810
# MSE (true vs. predicted):   0.065962
# KLD (true vs. control):     0.004581
# KLD (true vs. predicted):   0.004226
# Pearson Top 20 DEG (true vs. control): -0.302945 | p-value: 0.194171
# Pearson Top 20 DEG (true vs. predicted): 0.824847 | p-value: 0.000008
# Evaluating double 30/130: TMSB4X+BAK1
# MMD (true vs. control):     0.293578
# MMD (true vs. predicted):   0.498575
# MSE (true vs. control):     0.069581
# MSE (true vs. predicted):   0.037112
# KLD (true vs. control):     0.001906
# KLD (true vs. predicted):   0.002286
# Pearson Top 20 DEG (true vs. control): 0.192573 | p-value: 0.415980
# Pearson Top 20 DEG (true vs. predicted): 0.228361 | p-value: 0.332855
# Evaluating double 31/130: MAPK1+IKZF3
# MMD (true vs. control):     0.400608
# MMD (true vs. predicted):   0.660137
# MSE (true vs. control):     0.088508
# MSE (true vs. predicted):   0.052582
# KLD (true vs. control):     0.005981
# KLD (true vs. predicted):   0.003995
# Pearson Top 20 DEG (true vs. control): 0.450156 | p-value: 0.046411
# Pearson Top 20 DEG (true vs. predicted): 0.899816 | p-value: 0.000000
# Evaluating double 32/130: BPGM+SAMD1
# MMD (true vs. control):     0.375474
# MMD (true vs. predicted):   0.568983
# MSE (true vs. control):     0.078449
# MSE (true vs. predicted):   0.044328
# KLD (true vs. control):     0.006881
# KLD (true vs. predicted):   0.004007
# Pearson Top 20 DEG (true vs. control): 0.300744 | p-value: 0.197593
# Pearson Top 20 DEG (true vs. predicted): 0.953500 | p-value: 0.000000
# Evaluating double 33/130: CEBPB+CEBPA
# MMD (true vs. control):     0.595543
# MMD (true vs. predicted):   1.080012
# MSE (true vs. control):     0.135231
# MSE (true vs. predicted):   0.098053
# KLD (true vs. control):     0.017332
# KLD (true vs. predicted):   0.011159
# Pearson Top 20 DEG (true vs. control): -0.091573 | p-value: 0.701003
# Pearson Top 20 DEG (true vs. predicted): 0.918998 | p-value: 0.000000
# Evaluating double 34/130: KIF18B+KIF2C
# MMD (true vs. control):     0.303889
# MMD (true vs. predicted):   0.572802
# MSE (true vs. control):     0.082486
# MSE (true vs. predicted):   0.049409
# KLD (true vs. control):     0.001004
# KLD (true vs. predicted):   0.001111
# Pearson Top 20 DEG (true vs. control): -0.036413 | p-value: 0.878864
# Pearson Top 20 DEG (true vs. predicted): 0.756841 | p-value: 0.000112
# Evaluating double 35/130: FOXL2+MEIS1
# MMD (true vs. control):     0.334974
# MMD (true vs. predicted):   0.586258
# MSE (true vs. control):     0.081712
# MSE (true vs. predicted):   0.049244
# KLD (true vs. control):     0.002058
# KLD (true vs. predicted):   0.002119
# Pearson Top 20 DEG (true vs. control): 0.156783 | p-value: 0.509185
# Pearson Top 20 DEG (true vs. predicted): 0.664971 | p-value: 0.001379
# Evaluating double 36/130: MAPK1+TGFBR2
# MMD (true vs. control):     0.328903
# MMD (true vs. predicted):   0.544775
# MSE (true vs. control):     0.072211
# MSE (true vs. predicted):   0.040239
# KLD (true vs. control):     0.002184
# KLD (true vs. predicted):   0.002144
# Pearson Top 20 DEG (true vs. control): 0.243867 | p-value: 0.300140
# Pearson Top 20 DEG (true vs. predicted): 0.856924 | p-value: 0.000001
# Evaluating double 37/130: SNAI1+DLX2
# MMD (true vs. control):     0.371716
# MMD (true vs. predicted):   0.634611
# MSE (true vs. control):     0.087385
# MSE (true vs. predicted):   0.054431
# KLD (true vs. control):     0.003571
# KLD (true vs. predicted):   0.002977
# Pearson Top 20 DEG (true vs. control): -0.183120 | p-value: 0.439655
# Pearson Top 20 DEG (true vs. predicted): 0.760827 | p-value: 0.000098
# Evaluating double 38/130: ETS2+IGDCC3
# MMD (true vs. control):     0.315702
# MMD (true vs. predicted):   0.546507
# MSE (true vs. control):     0.072379
# MSE (true vs. predicted):   0.040167
# KLD (true vs. control):     0.001725
# KLD (true vs. predicted):   0.002002
# Pearson Top 20 DEG (true vs. control): 0.129597 | p-value: 0.586055
# Pearson Top 20 DEG (true vs. predicted): 0.449958 | p-value: 0.046519
# Evaluating double 39/130: KLF1+CLDN6
# MMD (true vs. control):     0.406621
# MMD (true vs. predicted):   0.727863
# MSE (true vs. control):     0.084243
# MSE (true vs. predicted):   0.052899
# KLD (true vs. control):     0.009026
# KLD (true vs. predicted):   0.007142
# Pearson Top 20 DEG (true vs. control): 0.260388 | p-value: 0.267527
# Pearson Top 20 DEG (true vs. predicted): 0.740992 | p-value: 0.000186
# Evaluating double 40/130: PRDM1+CBFA2T3
# MMD (true vs. control):     0.430367
# MMD (true vs. predicted):   0.801237
# MSE (true vs. control):     0.101201
# MSE (true vs. predicted):   0.069706
# KLD (true vs. control):     0.005187
# KLD (true vs. predicted):   0.005828
# Pearson Top 20 DEG (true vs. control): 0.007198 | p-value: 0.975972
# Pearson Top 20 DEG (true vs. predicted): 0.043208 | p-value: 0.856467
# Evaluating double 41/130: FOXA1+HOXB9
# MMD (true vs. control):     0.415694
# MMD (true vs. predicted):   0.743431
# MSE (true vs. control):     0.101440
# MSE (true vs. predicted):   0.066831
# KLD (true vs. control):     0.004590
# KLD (true vs. predicted):   0.004032
# Pearson Top 20 DEG (true vs. control): -0.188154 | p-value: 0.426960
# Pearson Top 20 DEG (true vs. predicted): 0.761177 | p-value: 0.000097
# Evaluating double 42/130: ZNF318+FOXL2
# MMD (true vs. control):     0.326817
# MMD (true vs. predicted):   0.597743
# MSE (true vs. control):     0.078452
# MSE (true vs. predicted):   0.045353
# KLD (true vs. control):     0.001887
# KLD (true vs. predicted):   0.002319
# Pearson Top 20 DEG (true vs. control): 0.286720 | p-value: 0.220340
# Pearson Top 20 DEG (true vs. predicted): 0.605459 | p-value: 0.004671
# Evaluating double 43/130: UBASH3B+PTPN9
# MMD (true vs. control):     0.383170
# MMD (true vs. predicted):   0.589168
# MSE (true vs. control):     0.078230
# MSE (true vs. predicted):   0.044729
# KLD (true vs. control):     0.004371
# KLD (true vs. predicted):   0.003004
# Pearson Top 20 DEG (true vs. control): 0.312000 | p-value: 0.180512
# Pearson Top 20 DEG (true vs. predicted): 0.906243 | p-value: 0.000000
# Evaluating double 44/130: PTPN12+UBASH3A
# MMD (true vs. control):     0.403156
# MMD (true vs. predicted):   0.600300
# MSE (true vs. control):     0.080104
# MSE (true vs. predicted):   0.045237
# KLD (true vs. control):     0.007441
# KLD (true vs. predicted):   0.005513
# Pearson Top 20 DEG (true vs. control): 0.168263 | p-value: 0.478248
# Pearson Top 20 DEG (true vs. predicted): 0.917833 | p-value: 0.000000
# Evaluating double 45/130: CEBPE+PTPN12
# MMD (true vs. control):     0.305412
# MMD (true vs. predicted):   0.689315
# MSE (true vs. control):     0.072543
# MSE (true vs. predicted):   0.047470
# KLD (true vs. control):     0.001554
# KLD (true vs. predicted):   0.004658
# Pearson Top 20 DEG (true vs. control): 0.034784 | p-value: 0.884248
# Pearson Top 20 DEG (true vs. predicted): 0.753668 | p-value: 0.000124
# Evaluating double 46/130: UBASH3B+ZBTB25
# MMD (true vs. control):     0.364828
# MMD (true vs. predicted):   0.573873
# MSE (true vs. control):     0.075540
# MSE (true vs. predicted):   0.042783
# KLD (true vs. control):     0.004418
# KLD (true vs. predicted):   0.003205
# Pearson Top 20 DEG (true vs. control): 0.480852 | p-value: 0.031854
# Pearson Top 20 DEG (true vs. predicted): 0.953172 | p-value: 0.000000
# Evaluating double 47/130: FOXA3+HOXB9
# MMD (true vs. control):     0.388413
# MMD (true vs. predicted):   0.706448
# MSE (true vs. control):     0.097164
# MSE (true vs. predicted):   0.064921
# KLD (true vs. control):     0.004113
# KLD (true vs. predicted):   0.004235
# Pearson Top 20 DEG (true vs. control): -0.168713 | p-value: 0.477055
# Pearson Top 20 DEG (true vs. predicted): 0.726633 | p-value: 0.000285
# Evaluating double 48/130: PTPN12+OSR2
# MMD (true vs. control):     0.293252
# MMD (true vs. predicted):   0.513646
# MSE (true vs. control):     0.069799
# MSE (true vs. predicted):   0.038205
# KLD (true vs. control):     0.001192
# KLD (true vs. predicted):   0.001582
# Pearson Top 20 DEG (true vs. control): 0.051542 | p-value: 0.829141
# Pearson Top 20 DEG (true vs. predicted): 0.745610 | p-value: 0.000161
# Evaluating double 49/130: FOXA3+FOXL2
# MMD (true vs. control):     0.428840
# MMD (true vs. predicted):   0.762467
# MSE (true vs. control):     0.100894
# MSE (true vs. predicted):   0.067280
# KLD (true vs. control):     0.005192
# KLD (true vs. predicted):   0.004808
# Pearson Top 20 DEG (true vs. control): -0.218251 | p-value: 0.355271
# Pearson Top 20 DEG (true vs. predicted): 0.654523 | p-value: 0.001740
# Evaluating double 50/130: FEV+MAP7D1
# MMD (true vs. control):     0.397263
# MMD (true vs. predicted):   0.719169
# MSE (true vs. control):     0.088651
# MSE (true vs. predicted):   0.058072
# KLD (true vs. control):     0.004977
# KLD (true vs. predicted):   0.004922
# Pearson Top 20 DEG (true vs. control): 0.295196 | p-value: 0.206396
# Pearson Top 20 DEG (true vs. predicted): 0.546369 | p-value: 0.012685
# Evaluating double 51/130: FOSB+UBASH3B
# MMD (true vs. control):     0.294699
# MMD (true vs. predicted):   0.481742
# MSE (true vs. control):     0.069115
# MSE (true vs. predicted):   0.037193
# KLD (true vs. control):     0.001099
# KLD (true vs. predicted):   0.001316
# Pearson Top 20 DEG (true vs. control): 0.446644 | p-value: 0.048358
# Pearson Top 20 DEG (true vs. predicted): 0.591546 | p-value: 0.006009
# Evaluating double 52/130: IRF1+SET
# MMD (true vs. control):     0.445160
# MMD (true vs. predicted):   0.728231
# MSE (true vs. control):     0.084499
# MSE (true vs. predicted):   0.052584
# KLD (true vs. control):     0.006661
# KLD (true vs. predicted):   0.006411
# Pearson Top 20 DEG (true vs. control): -0.231163 | p-value: 0.326792
# Pearson Top 20 DEG (true vs. predicted): 0.633197 | p-value: 0.002727
# Evaluating double 53/130: MAP2K6+SPI1
# MMD (true vs. control):     0.291944
# MMD (true vs. predicted):   0.464008
# MSE (true vs. control):     0.064390
# MSE (true vs. predicted):   0.034079
# KLD (true vs. control):     0.001122
# KLD (true vs. predicted):   0.001279
# Pearson Top 20 DEG (true vs. control): -0.103244 | p-value: 0.664903
# Pearson Top 20 DEG (true vs. predicted): 0.750354 | p-value: 0.000139
# Evaluating double 54/130: UBASH3B+UBASH3A
# MMD (true vs. control):     0.311363
# MMD (true vs. predicted):   0.519058
# MSE (true vs. control):     0.072202
# MSE (true vs. predicted):   0.039469
# KLD (true vs. control):     0.001638
# KLD (true vs. predicted):   0.001795
# Pearson Top 20 DEG (true vs. control): -0.049645 | p-value: 0.835346
# Pearson Top 20 DEG (true vs. predicted): 0.888842 | p-value: 0.000000
# Evaluating double 55/130: SAMD1+ZBTB1
# MMD (true vs. control):     0.430094
# MMD (true vs. predicted):   0.673623
# MSE (true vs. control):     0.093621
# MSE (true vs. predicted):   0.057345
# KLD (true vs. control):     0.007368
# KLD (true vs. predicted):   0.004741
# Pearson Top 20 DEG (true vs. control): -0.152493 | p-value: 0.520984
# Pearson Top 20 DEG (true vs. predicted): 0.887871 | p-value: 0.000000
# Evaluating double 56/130: POU3F2+CBFA2T3
# MMD (true vs. control):     0.348379
# MMD (true vs. predicted):   0.624359
# MSE (true vs. control):     0.087466
# MSE (true vs. predicted):   0.053514
# KLD (true vs. control):     0.002391
# KLD (true vs. predicted):   0.002514
# Pearson Top 20 DEG (true vs. control): -0.093853 | p-value: 0.693899
# Pearson Top 20 DEG (true vs. predicted): 0.663430 | p-value: 0.001428
# Evaluating double 57/130: AHR+FEV
# MMD (true vs. control):     0.540928
# MMD (true vs. predicted):   0.918523
# MSE (true vs. control):     0.116096
# MSE (true vs. predicted):   0.082698
# KLD (true vs. control):     0.012905
# KLD (true vs. predicted):   0.010901
# Pearson Top 20 DEG (true vs. control): 0.152047 | p-value: 0.522218
# Pearson Top 20 DEG (true vs. predicted): 0.746422 | p-value: 0.000157
# Evaluating double 58/130: MAPK1+PRTG
# MMD (true vs. control):     0.308228
# MMD (true vs. predicted):   0.491456
# MSE (true vs. control):     0.069495
# MSE (true vs. predicted):   0.036491
# KLD (true vs. control):     0.001521
# KLD (true vs. predicted):   0.001434
# Pearson Top 20 DEG (true vs. control): 0.214514 | p-value: 0.363773
# Pearson Top 20 DEG (true vs. predicted): 0.567675 | p-value: 0.009033
# Evaluating double 59/130: KLF1+MAP2K6
# MMD (true vs. control):     0.325133
# MMD (true vs. predicted):   0.563101
# MSE (true vs. control):     0.067984
# MSE (true vs. predicted):   0.038642
# KLD (true vs. control):     0.002592
# KLD (true vs. predicted):   0.003509
# Pearson Top 20 DEG (true vs. control): -0.214059 | p-value: 0.364816
# Pearson Top 20 DEG (true vs. predicted): 0.658912 | p-value: 0.001580
# Evaluating double 60/130: RHOXF2+SET
# MMD (true vs. control):     0.399558
# MMD (true vs. predicted):   0.702266
# MSE (true vs. control):     0.087271
# MSE (true vs. predicted):   0.055189
# KLD (true vs. control):     0.003928
# KLD (true vs. predicted):   0.003704
# Pearson Top 20 DEG (true vs. control): -0.096852 | p-value: 0.684593
# Pearson Top 20 DEG (true vs. predicted): 0.725809 | p-value: 0.000292
# Evaluating double 61/130: PTPN12+PTPN9
# MMD (true vs. control):     0.378696
# MMD (true vs. predicted):   0.582136
# MSE (true vs. control):     0.077327
# MSE (true vs. predicted):   0.043639
# KLD (true vs. control):     0.005439
# KLD (true vs. predicted):   0.003614
# Pearson Top 20 DEG (true vs. control): 0.261023 | p-value: 0.266320
# Pearson Top 20 DEG (true vs. predicted): 0.939541 | p-value: 0.000000
# Evaluating double 62/130: CNN1+UBASH3A
# MMD (true vs. control):     0.435481
# MMD (true vs. predicted):   0.810026
# MSE (true vs. control):     0.093121
# MSE (true vs. predicted):   0.062919
# KLD (true vs. control):     0.009320
# KLD (true vs. predicted):   0.008378
# Pearson Top 20 DEG (true vs. control): -0.283520 | p-value: 0.225761
# Pearson Top 20 DEG (true vs. predicted): 0.733365 | p-value: 0.000234
# Evaluating double 63/130: KLF1+CEBPA
# MMD (true vs. control):     0.514327
# MMD (true vs. predicted):   0.838436
# MSE (true vs. control):     0.112663
# MSE (true vs. predicted):   0.074481
# KLD (true vs. control):     0.011129
# KLD (true vs. predicted):   0.005337
# Pearson Top 20 DEG (true vs. control): 0.081369 | p-value: 0.733081
# Pearson Top 20 DEG (true vs. predicted): 0.938616 | p-value: 0.000000
# Evaluating double 64/130: ETS2+MAPK1
# MMD (true vs. control):     0.443898
# MMD (true vs. predicted):   0.758961
# MSE (true vs. control):     0.089437
# MSE (true vs. predicted):   0.056687
# KLD (true vs. control):     0.007055
# KLD (true vs. predicted):   0.007263
# Pearson Top 20 DEG (true vs. control): 0.133251 | p-value: 0.575443
# Pearson Top 20 DEG (true vs. predicted): 0.910097 | p-value: 0.000000
# Evaluating double 65/130: FEV+CBFA2T3
# MMD (true vs. control):     0.533876
# MMD (true vs. predicted):   0.931334
# MSE (true vs. control):     0.117076
# MSE (true vs. predicted):   0.083264
# KLD (true vs. control):     0.010133
# KLD (true vs. predicted):   0.009478
# Pearson Top 20 DEG (true vs. control): 0.020682 | p-value: 0.931032
# Pearson Top 20 DEG (true vs. predicted): 0.542539 | p-value: 0.013452
# Evaluating double 66/130: SGK1+TBX2
# MMD (true vs. control):     0.377890
# MMD (true vs. predicted):   0.597748
# MSE (true vs. control):     0.081467
# MSE (true vs. predicted):   0.046549
# KLD (true vs. control):     0.004811
# KLD (true vs. predicted):   0.003324
# Pearson Top 20 DEG (true vs. control): 0.472579 | p-value: 0.035366
# Pearson Top 20 DEG (true vs. predicted): 0.929718 | p-value: 0.000000
# Evaluating double 67/130: SAMD1+TGFBR2
# MMD (true vs. control):     0.330257
# MMD (true vs. predicted):   0.572591
# MSE (true vs. control):     0.076650
# MSE (true vs. predicted):   0.044495
# KLD (true vs. control):     0.003033
# KLD (true vs. predicted):   0.002433
# Pearson Top 20 DEG (true vs. control): 0.269550 | p-value: 0.250442
# Pearson Top 20 DEG (true vs. predicted): 0.890372 | p-value: 0.000000
# Evaluating double 68/130: MAP2K6+ELMSAN1
# MMD (true vs. control):     0.296264
# MMD (true vs. predicted):   0.465307
# MSE (true vs. control):     0.061505
# MSE (true vs. predicted):   0.031022
# KLD (true vs. control):     0.001217
# KLD (true vs. predicted):   0.001823
# Pearson Top 20 DEG (true vs. control): 0.377133 | p-value: 0.101176
# Pearson Top 20 DEG (true vs. predicted): 0.889196 | p-value: 0.000000
# Evaluating double 69/130: SNAI1+UBASH3B
# MMD (true vs. control):     0.319902
# MMD (true vs. predicted):   0.522265
# MSE (true vs. control):     0.075010
# MSE (true vs. predicted):   0.042221
# KLD (true vs. control):     0.001664
# KLD (true vs. predicted):   0.001464
# Pearson Top 20 DEG (true vs. control): -0.148848 | p-value: 0.531110
# Pearson Top 20 DEG (true vs. predicted): 0.690937 | p-value: 0.000743
# Evaluating double 70/130: PTPN12+ZBTB25
# MMD (true vs. control):     0.393500
# MMD (true vs. predicted):   0.597216
# MSE (true vs. control):     0.078626
# MSE (true vs. predicted):   0.045242
# KLD (true vs. control):     0.007446
# KLD (true vs. predicted):   0.004940
# Pearson Top 20 DEG (true vs. control): 0.679757 | p-value: 0.000977
# Pearson Top 20 DEG (true vs. predicted): 0.947867 | p-value: 0.000000
# Evaluating double 71/130: CEBPE+KLF1
# MMD (true vs. control):     0.305381
# MMD (true vs. predicted):   0.582866
# MSE (true vs. control):     0.071933
# MSE (true vs. predicted):   0.042216
# KLD (true vs. control):     0.001634
# KLD (true vs. predicted):   0.002852
# Pearson Top 20 DEG (true vs. control): -0.018793 | p-value: 0.937318
# Pearson Top 20 DEG (true vs. predicted): 0.387190 | p-value: 0.091681
# Evaluating double 72/130: TGFBR2+ETS2
# MMD (true vs. control):     0.302565
# MMD (true vs. predicted):   0.510073
# MSE (true vs. control):     0.068539
# MSE (true vs. predicted):   0.037297
# KLD (true vs. control):     0.001369
# KLD (true vs. predicted):   0.001878
# Pearson Top 20 DEG (true vs. control): -0.053558 | p-value: 0.822557
# Pearson Top 20 DEG (true vs. predicted): 0.888190 | p-value: 0.000000
# Evaluating double 73/130: FOSB+IKZF3
# MMD (true vs. control):     0.350591
# MMD (true vs. predicted):   0.634192
# MSE (true vs. control):     0.081377
# MSE (true vs. predicted):   0.048689
# KLD (true vs. control):     0.004057
# KLD (true vs. predicted):   0.003143
# Pearson Top 20 DEG (true vs. control): 0.320415 | p-value: 0.168417
# Pearson Top 20 DEG (true vs. predicted): 0.938499 | p-value: 0.000000
# Evaluating double 74/130: FOXA3+FOXA1
# MMD (true vs. control):     0.377189
# MMD (true vs. predicted):   0.641692
# MSE (true vs. control):     0.087237
# MSE (true vs. predicted):   0.053336
# KLD (true vs. control):     0.003486
# KLD (true vs. predicted):   0.002926
# Pearson Top 20 DEG (true vs. control): -0.017497 | p-value: 0.941636
# Pearson Top 20 DEG (true vs. predicted): 0.795566 | p-value: 0.000027
# Evaluating double 75/130: ETS2+PRTG
# MMD (true vs. control):     0.331295
# MMD (true vs. predicted):   0.539590
# MSE (true vs. control):     0.076750
# MSE (true vs. predicted):   0.042975
# KLD (true vs. control):     0.002209
# KLD (true vs. predicted):   0.001612
# Pearson Top 20 DEG (true vs. control): 0.249595 | p-value: 0.288571
# Pearson Top 20 DEG (true vs. predicted): 0.836793 | p-value: 0.000004
# Evaluating double 76/130: SET+KLF1
# MMD (true vs. control):     0.361115
# MMD (true vs. predicted):   0.562567
# MSE (true vs. control):     0.072837
# MSE (true vs. predicted):   0.039285
# KLD (true vs. control):     0.003868
# KLD (true vs. predicted):   0.003370
# Pearson Top 20 DEG (true vs. control): -0.185086 | p-value: 0.434674
# Pearson Top 20 DEG (true vs. predicted): 0.749933 | p-value: 0.000140
# Evaluating double 77/130: ZC3HAV1+HOXC13
# MMD (true vs. control):     0.310843
# MMD (true vs. predicted):   0.532190
# MSE (true vs. control):     0.078503
# MSE (true vs. predicted):   0.045766
# KLD (true vs. control):     0.001645
# KLD (true vs. predicted):   0.001444
# Pearson Top 20 DEG (true vs. control): -0.260744 | p-value: 0.266850
# Pearson Top 20 DEG (true vs. predicted): 0.721326 | p-value: 0.000332
# Evaluating double 78/130: TBX3+TBX2
# MMD (true vs. control):     0.373724
# MMD (true vs. predicted):   0.874974
# MSE (true vs. control):     0.079070
# MSE (true vs. predicted):   0.056670
# KLD (true vs. control):     0.009936
# KLD (true vs. predicted):   0.012015
# Pearson Top 20 DEG (true vs. control): -0.176645 | p-value: 0.456271
# Pearson Top 20 DEG (true vs. predicted): 0.770957 | p-value: 0.000069
# Evaluating double 79/130: KLF1+COL2A1
# MMD (true vs. control):     0.360975
# MMD (true vs. predicted):   0.611541
# MSE (true vs. control):     0.071536
# MSE (true vs. predicted):   0.040943
# KLD (true vs. control):     0.003787
# KLD (true vs. predicted):   0.004489
# Pearson Top 20 DEG (true vs. control): -0.353642 | p-value: 0.126110
# Pearson Top 20 DEG (true vs. predicted): 0.591955 | p-value: 0.005966
# Evaluating double 80/130: CBL+TGFBR2
# MMD (true vs. control):     0.333563
# MMD (true vs. predicted):   0.504770
# MSE (true vs. control):     0.071327
# MSE (true vs. predicted):   0.036738
# KLD (true vs. control):     0.003301
# KLD (true vs. predicted):   0.002227
# Pearson Top 20 DEG (true vs. control): 0.198146 | p-value: 0.402353
# Pearson Top 20 DEG (true vs. predicted): 0.942261 | p-value: 0.000000
# Evaluating double 81/130: TGFBR2+IGDCC3
# MMD (true vs. control):     0.337705
# MMD (true vs. predicted):   0.542715
# MSE (true vs. control):     0.075291
# MSE (true vs. predicted):   0.042429
# KLD (true vs. control):     0.003356
# KLD (true vs. predicted):   0.002486
# Pearson Top 20 DEG (true vs. control): 0.029782 | p-value: 0.900809
# Pearson Top 20 DEG (true vs. predicted): 0.898475 | p-value: 0.000000
# Evaluating double 82/130: MAP2K3+IKZF3
# MMD (true vs. control):     0.398343
# MMD (true vs. predicted):   0.638023
# MSE (true vs. control):     0.080775
# MSE (true vs. predicted):   0.046718
# KLD (true vs. control):     0.011550
# KLD (true vs. predicted):   0.006615
# Pearson Top 20 DEG (true vs. control): 0.146084 | p-value: 0.538851
# Pearson Top 20 DEG (true vs. predicted): 0.905970 | p-value: 0.000000
# Evaluating double 83/130: SET+CEBPE
# MMD (true vs. control):     0.354384
# MMD (true vs. predicted):   0.735956
# MSE (true vs. control):     0.075908
# MSE (true vs. predicted):   0.049361
# KLD (true vs. control):     0.003257
# KLD (true vs. predicted):   0.006104
# Pearson Top 20 DEG (true vs. control): -0.134923 | p-value: 0.570616
# Pearson Top 20 DEG (true vs. predicted): 0.768482 | p-value: 0.000076
# Evaluating double 84/130: ZBTB10+DLX2
# MMD (true vs. control):     0.509838
# MMD (true vs. predicted):   0.883305
# MSE (true vs. control):     0.117386
# MSE (true vs. predicted):   0.081826
# KLD (true vs. control):     0.009164
# KLD (true vs. predicted):   0.008153
# Pearson Top 20 DEG (true vs. control): 0.167487 | p-value: 0.480308
# Pearson Top 20 DEG (true vs. predicted): 0.804532 | p-value: 0.000019
# Evaluating double 85/130: DUSP9+ETS2
# MMD (true vs. control):     0.336675
# MMD (true vs. predicted):   0.576250
# MSE (true vs. control):     0.077436
# MSE (true vs. predicted):   0.044958
# KLD (true vs. control):     0.002920
# KLD (true vs. predicted):   0.002523
# Pearson Top 20 DEG (true vs. control): 0.220369 | p-value: 0.350504
# Pearson Top 20 DEG (true vs. predicted): 0.852762 | p-value: 0.000002
# Evaluating double 86/130: CEBPB+MAPK1
# MMD (true vs. control):     0.394340
# MMD (true vs. predicted):   0.657506
# MSE (true vs. control):     0.081976
# MSE (true vs. predicted):   0.048903
# KLD (true vs. control):     0.004812
# KLD (true vs. predicted):   0.004650
# Pearson Top 20 DEG (true vs. control): 0.270798 | p-value: 0.248170
# Pearson Top 20 DEG (true vs. predicted): 0.940322 | p-value: 0.000000
# Evaluating double 87/130: POU3F2+FOXL2
# MMD (true vs. control):     0.361125
# MMD (true vs. predicted):   0.651041
# MSE (true vs. control):     0.089695
# MSE (true vs. predicted):   0.056757
# KLD (true vs. control):     0.002817
# KLD (true vs. predicted):   0.002510
# Pearson Top 20 DEG (true vs. control): 0.069910 | p-value: 0.769617
# Pearson Top 20 DEG (true vs. predicted): 0.813473 | p-value: 0.000013
# Evaluating double 88/130: CNN1+MAPK1
# MMD (true vs. control):     0.318942
# MMD (true vs. predicted):   0.548407
# MSE (true vs. control):     0.076917
# MSE (true vs. predicted):   0.044592
# KLD (true vs. control):     0.001708
# KLD (true vs. predicted):   0.001924
# Pearson Top 20 DEG (true vs. control): 0.265426 | p-value: 0.258045
# Pearson Top 20 DEG (true vs. predicted): 0.022172 | p-value: 0.926077
# Evaluating double 89/130: CEBPE+CEBPA
# MMD (true vs. control):     0.489810
# MMD (true vs. predicted):   1.264246
# MSE (true vs. control):     0.118682
# MSE (true vs. predicted):   0.100846
# KLD (true vs. control):     0.011375
# KLD (true vs. predicted):   0.018047
# Pearson Top 20 DEG (true vs. control): -0.121523 | p-value: 0.609792
# Pearson Top 20 DEG (true vs. predicted): 0.948634 | p-value: 0.000000
# Evaluating double 90/130: UBASH3B+CNN1
# MMD (true vs. control):     0.443325
# MMD (true vs. predicted):   0.765414
# MSE (true vs. control):     0.088805
# MSE (true vs. predicted):   0.056337
# KLD (true vs. control):     0.011159
# KLD (true vs. predicted):   0.007622
# Pearson Top 20 DEG (true vs. control): 0.185456 | p-value: 0.433740
# Pearson Top 20 DEG (true vs. predicted): 0.913118 | p-value: 0.000000
# Evaluating double 91/130: ETS2+CNN1
# MMD (true vs. control):     0.313159
# MMD (true vs. predicted):   0.524929
# MSE (true vs. control):     0.071850
# MSE (true vs. predicted):   0.040096
# KLD (true vs. control):     0.001650
# KLD (true vs. predicted):   0.001481
# Pearson Top 20 DEG (true vs. control): -0.055924 | p-value: 0.814848
# Pearson Top 20 DEG (true vs. predicted): 0.680663 | p-value: 0.000956
# Evaluating double 92/130: DUSP9+IGDCC3
# MMD (true vs. control):     0.416800
# MMD (true vs. predicted):   0.671225
# MSE (true vs. control):     0.085465
# MSE (true vs. predicted):   0.051156
# KLD (true vs. control):     0.007784
# KLD (true vs. predicted):   0.004757
# Pearson Top 20 DEG (true vs. control): 0.324971 | p-value: 0.162106
# Pearson Top 20 DEG (true vs. predicted): 0.954540 | p-value: 0.000000
# Evaluating double 93/130: PTPN12+SNAI1
# MMD (true vs. control):     0.312846
# MMD (true vs. predicted):   0.538650
# MSE (true vs. control):     0.076901
# MSE (true vs. predicted):   0.044508
# KLD (true vs. control):     0.001422
# KLD (true vs. predicted):   0.001309
# Pearson Top 20 DEG (true vs. control): 0.034484 | p-value: 0.885239
# Pearson Top 20 DEG (true vs. predicted): 0.670696 | p-value: 0.001209
# Evaluating double 94/130: FOXA1+FOXF1
# MMD (true vs. control):     0.325875
# MMD (true vs. predicted):   0.568903
# MSE (true vs. control):     0.080202
# MSE (true vs. predicted):   0.048087
# KLD (true vs. control):     0.001925
# KLD (true vs. predicted):   0.001920
# Pearson Top 20 DEG (true vs. control): 0.277640 | p-value: 0.235949
# Pearson Top 20 DEG (true vs. predicted): 0.643684 | p-value: 0.002196
# Evaluating double 95/130: CEBPE+CNN1
# MMD (true vs. control):     0.343781
# MMD (true vs. predicted):   0.578254
# MSE (true vs. control):     0.080920
# MSE (true vs. predicted):   0.047658
# KLD (true vs. control):     0.002813
# KLD (true vs. predicted):   0.002092
# Pearson Top 20 DEG (true vs. control): -0.021374 | p-value: 0.928731
# Pearson Top 20 DEG (true vs. predicted): 0.747838 | p-value: 0.000150
# Evaluating double 96/130: TGFBR2+PRTG
# MMD (true vs. control):     0.346585
# MMD (true vs. predicted):   0.576128
# MSE (true vs. control):     0.076980
# MSE (true vs. predicted):   0.043981
# KLD (true vs. control):     0.003596
# KLD (true vs. predicted):   0.002558
# Pearson Top 20 DEG (true vs. control): 0.092861 | p-value: 0.696988
# Pearson Top 20 DEG (true vs. predicted): 0.934707 | p-value: 0.000000
# Evaluating double 97/130: FOXF1+HOXB9
# MMD (true vs. control):     0.370489
# MMD (true vs. predicted):   0.671513
# MSE (true vs. control):     0.088948
# MSE (true vs. predicted):   0.057169
# KLD (true vs. control):     0.003008
# KLD (true vs. predicted):   0.003096
# Pearson Top 20 DEG (true vs. control): -0.212931 | p-value: 0.367407
# Pearson Top 20 DEG (true vs. predicted): 0.709276 | p-value: 0.000462
# Evaluating double 98/130: CEBPE+RUNX1T1
# MMD (true vs. control):     0.314176
# MMD (true vs. predicted):   0.537364
# MSE (true vs. control):     0.073834
# MSE (true vs. predicted):   0.040900
# KLD (true vs. control):     0.001819
# KLD (true vs. predicted):   0.001968
# Pearson Top 20 DEG (true vs. control): -0.022702 | p-value: 0.924314
# Pearson Top 20 DEG (true vs. predicted): 0.958797 | p-value: 0.000000
# Evaluating double 99/130: CBL+PTPN12
# MMD (true vs. control):     0.367065
# MMD (true vs. predicted):   0.545423
# MSE (true vs. control):     0.074856
# MSE (true vs. predicted):   0.040477
# KLD (true vs. control):     0.005950
# KLD (true vs. predicted):   0.003394
# Pearson Top 20 DEG (true vs. control): 0.086790 | p-value: 0.715983
# Pearson Top 20 DEG (true vs. predicted): 0.962644 | p-value: 0.000000
# Evaluating double 100/130: FOXF1+FOXL2
# MMD (true vs. control):     0.381708
# MMD (true vs. predicted):   0.650622
# MSE (true vs. control):     0.092645
# MSE (true vs. predicted):   0.058844
# KLD (true vs. control):     0.003968
# KLD (true vs. predicted):   0.003324
# Pearson Top 20 DEG (true vs. control): -0.211865 | p-value: 0.369868
# Pearson Top 20 DEG (true vs. predicted): 0.822128 | p-value: 0.000009
# Evaluating double 101/130: KLF1+FOXA1
# MMD (true vs. control):     0.337965
# MMD (true vs. predicted):   0.564725
# MSE (true vs. control):     0.080031
# MSE (true vs. predicted):   0.047004
# KLD (true vs. control):     0.002754
# KLD (true vs. predicted):   0.002555
# Pearson Top 20 DEG (true vs. control): 0.082559 | p-value: 0.729318
# Pearson Top 20 DEG (true vs. predicted): 0.433866 | p-value: 0.055971
# Evaluating double 102/130: MAP2K6+IKZF3
# MMD (true vs. control):     0.416876
# MMD (true vs. predicted):   0.660764
# MSE (true vs. control):     0.086831
# MSE (true vs. predicted):   0.052665
# KLD (true vs. control):     0.010701
# KLD (true vs. predicted):   0.006923
# Pearson Top 20 DEG (true vs. control): 0.191158 | p-value: 0.419480
# Pearson Top 20 DEG (true vs. predicted): 0.909711 | p-value: 0.000000
# Evaluating double 103/130: CEBPB+OSR2
# MMD (true vs. control):     0.443256
# MMD (true vs. predicted):   0.794090
# MSE (true vs. control):     0.100050
# MSE (true vs. predicted):   0.068277
# KLD (true vs. control):     0.007252
# KLD (true vs. predicted):   0.006224
# Pearson Top 20 DEG (true vs. control): 0.061229 | p-value: 0.797616
# Pearson Top 20 DEG (true vs. predicted): 0.911365 | p-value: 0.000000
# Evaluating double 104/130: CDKN1C+CDKN1A
# MMD (true vs. control):     0.355466
# MMD (true vs. predicted):   0.560462
# MSE (true vs. control):     0.078867
# MSE (true vs. predicted):   0.044398
# KLD (true vs. control):     0.003163
# KLD (true vs. predicted):   0.002172
# Pearson Top 20 DEG (true vs. control): 0.304724 | p-value: 0.191434
# Pearson Top 20 DEG (true vs. predicted): 0.925976 | p-value: 0.000000
# Evaluating double 105/130: JUN+CEBPA
# MMD (true vs. control):     0.637342
# MMD (true vs. predicted):   1.216164
# MSE (true vs. control):     0.136240
# MSE (true vs. predicted):   0.103607
# KLD (true vs. control):     0.020216
# KLD (true vs. predicted):   0.015546
# Pearson Top 20 DEG (true vs. control): -0.097688 | p-value: 0.682006
# Pearson Top 20 DEG (true vs. predicted): 0.956725 | p-value: 0.000000
# Evaluating double 106/130: IGDCC3+MAPK1
# MMD (true vs. control):     0.307575
# MMD (true vs. predicted):   0.509129
# MSE (true vs. control):     0.073863
# MSE (true vs. predicted):   0.041294
# KLD (true vs. control):     0.001533
# KLD (true vs. predicted):   0.001559
# Pearson Top 20 DEG (true vs. control): 0.265566 | p-value: 0.257784
# Pearson Top 20 DEG (true vs. predicted): 0.528098 | p-value: 0.016691
# Evaluating double 107/130: KLF1+BAK1
# MMD (true vs. control):     0.320177
# MMD (true vs. predicted):   0.494312
# MSE (true vs. control):     0.067671
# MSE (true vs. predicted):   0.035465
# KLD (true vs. control):     0.002427
# KLD (true vs. predicted):   0.002408
# Pearson Top 20 DEG (true vs. control): -0.181268 | p-value: 0.444375
# Pearson Top 20 DEG (true vs. predicted): 0.656895 | p-value: 0.001652
# Evaluating double 108/130: ZBTB10+ELMSAN1
# MMD (true vs. control):     0.414473
# MMD (true vs. predicted):   0.721191
# MSE (true vs. control):     0.099712
# MSE (true vs. predicted):   0.065415
# KLD (true vs. control):     0.005088
# KLD (true vs. predicted):   0.004470
# Pearson Top 20 DEG (true vs. control): -0.169179 | p-value: 0.475820
# Pearson Top 20 DEG (true vs. predicted): 0.316356 | p-value: 0.174179
# Evaluating double 109/130: FOSB+PTPN12
# MMD (true vs. control):     0.301709
# MMD (true vs. predicted):   0.524812
# MSE (true vs. control):     0.068425
# MSE (true vs. predicted):   0.038212
# KLD (true vs. control):     0.001435
# KLD (true vs. predicted):   0.002215
# Pearson Top 20 DEG (true vs. control): 0.107790 | p-value: 0.651027
# Pearson Top 20 DEG (true vs. predicted): 0.166777 | p-value: 0.482198
# Evaluating double 110/130: ZBTB10+SNAI1
# MMD (true vs. control):     0.501325
# MMD (true vs. predicted):   0.849224
# MSE (true vs. control):     0.116650
# MSE (true vs. predicted):   0.080522
# KLD (true vs. control):     0.008705
# KLD (true vs. predicted):   0.007527
# Pearson Top 20 DEG (true vs. control): 0.007089 | p-value: 0.976338
# Pearson Top 20 DEG (true vs. predicted): 0.791074 | p-value: 0.000033
# Evaluating double 111/130: SAMD1+PTPN12
# MMD (true vs. control):     0.400036
# MMD (true vs. predicted):   0.683381
# MSE (true vs. control):     0.085295
# MSE (true vs. predicted):   0.052253
# KLD (true vs. control):     0.006895
# KLD (true vs. predicted):   0.005079
# Pearson Top 20 DEG (true vs. control): 0.587282 | p-value: 0.006478
# Pearson Top 20 DEG (true vs. predicted): 0.877975 | p-value: 0.000000
# Evaluating double 112/130: PLK4+STIL
# MMD (true vs. control):     0.298064
# MMD (true vs. predicted):   0.532331
# MSE (true vs. control):     0.078236
# MSE (true vs. predicted):   0.045989
# KLD (true vs. control):     0.001145
# KLD (true vs. predicted):   0.001152
# Pearson Top 20 DEG (true vs. control): 0.074027 | p-value: 0.756434
# Pearson Top 20 DEG (true vs. predicted): 0.743019 | p-value: 0.000175
# Evaluating double 113/130: TGFBR2+C19orf26
# MMD (true vs. control):     0.337098
# MMD (true vs. predicted):   0.531919
# MSE (true vs. control):     0.071274
# MSE (true vs. predicted):   0.039796
# KLD (true vs. control):     0.002747
# KLD (true vs. predicted):   0.002594
# Pearson Top 20 DEG (true vs. control): 0.260664 | p-value: 0.267003
# Pearson Top 20 DEG (true vs. predicted): 0.688073 | p-value: 0.000798
# Evaluating double 114/130: BPGM+ZBTB1
# MMD (true vs. control):     0.352488
# MMD (true vs. predicted):   0.661238
# MSE (true vs. control):     0.077906
# MSE (true vs. predicted):   0.047469
# KLD (true vs. control):     0.004275
# KLD (true vs. predicted):   0.004380
# Pearson Top 20 DEG (true vs. control): 0.163965 | p-value: 0.489720
# Pearson Top 20 DEG (true vs. predicted): 0.867087 | p-value: 0.000001
# Evaluating double 115/130: BCL2L11+TGFBR2
# MMD (true vs. control):     0.289285
# MMD (true vs. predicted):   0.575780
# MSE (true vs. control):     0.066978
# MSE (true vs. predicted):   0.038630
# KLD (true vs. control):     0.001061
# KLD (true vs. predicted):   0.003115
# Pearson Top 20 DEG (true vs. control): -0.226769 | p-value: 0.336328
# Pearson Top 20 DEG (true vs. predicted): 0.807776 | p-value: 0.000017
# Evaluating double 116/130: SGK1+TBX3
# MMD (true vs. control):     0.377273
# MMD (true vs. predicted):   0.848378
# MSE (true vs. control):     0.081653
# MSE (true vs. predicted):   0.057200
# KLD (true vs. control):     0.015054
# KLD (true vs. predicted):   0.008427
# Pearson Top 20 DEG (true vs. control): -0.409738 | p-value: 0.072790
# Pearson Top 20 DEG (true vs. predicted): 0.901338 | p-value: 0.000000
# Evaluating double 117/130: FOSB+OSR2
# MMD (true vs. control):     0.402196
# MMD (true vs. predicted):   0.697787
# MSE (true vs. control):     0.088992
# MSE (true vs. predicted):   0.056396
# KLD (true vs. control):     0.005984
# KLD (true vs. predicted):   0.005432
# Pearson Top 20 DEG (true vs. control): -0.045277 | p-value: 0.849667
# Pearson Top 20 DEG (true vs. predicted): 0.922939 | p-value: 0.000000
# Evaluating double 118/130: UBASH3B+OSR2
# MMD (true vs. control):     0.293693
# MMD (true vs. predicted):   0.472534
# MSE (true vs. control):     0.069154
# MSE (true vs. predicted):   0.036311
# KLD (true vs. control):     0.001441
# KLD (true vs. predicted):   0.001593
# Pearson Top 20 DEG (true vs. control): 0.077648 | p-value: 0.744889
# Pearson Top 20 DEG (true vs. predicted): 0.480861 | p-value: 0.031850
# Evaluating double 119/130: CBL+UBASH3A
# MMD (true vs. control):     0.334323
# MMD (true vs. predicted):   0.565086
# MSE (true vs. control):     0.084292
# MSE (true vs. predicted):   0.050304
# KLD (true vs. control):     0.002647
# KLD (true vs. predicted):   0.001803
# Pearson Top 20 DEG (true vs. control): 0.178110 | p-value: 0.452484
# Pearson Top 20 DEG (true vs. predicted): 0.901193 | p-value: 0.000000
# Evaluating double 120/130: DUSP9+MAPK1
# MMD (true vs. control):     0.312158
# MMD (true vs. predicted):   0.556527
# MSE (true vs. control):     0.071241
# MSE (true vs. predicted):   0.039662
# KLD (true vs. control):     0.001860
# KLD (true vs. predicted):   0.002423
# Pearson Top 20 DEG (true vs. control): 0.184962 | p-value: 0.434987
# Pearson Top 20 DEG (true vs. predicted): 0.731695 | p-value: 0.000246
# Evaluating double 121/130: IGDCC3+PRTG
# MMD (true vs. control):     0.350742
# MMD (true vs. predicted):   0.600982
# MSE (true vs. control):     0.077424
# MSE (true vs. predicted):   0.046448
# KLD (true vs. control):     0.003284
# KLD (true vs. predicted):   0.002997
# Pearson Top 20 DEG (true vs. control): 0.034309 | p-value: 0.885820
# Pearson Top 20 DEG (true vs. predicted): 0.899371 | p-value: 0.000000
# Evaluating double 122/130: MAP2K3+ELMSAN1
# MMD (true vs. control):     0.316738
# MMD (true vs. predicted):   0.509217
# MSE (true vs. control):     0.067557
# MSE (true vs. predicted):   0.035890
# KLD (true vs. control):     0.001892
# KLD (true vs. predicted):   0.002426
# Pearson Top 20 DEG (true vs. control): 0.177572 | p-value: 0.453871
# Pearson Top 20 DEG (true vs. predicted): 0.669322 | p-value: 0.001248
# Evaluating double 123/130: LHX1+ELMSAN1
# MMD (true vs. control):     0.337711
# MMD (true vs. predicted):   0.558436
# MSE (true vs. control):     0.077565
# MSE (true vs. predicted):   0.044129
# KLD (true vs. control):     0.003397
# KLD (true vs. predicted):   0.002897
# Pearson Top 20 DEG (true vs. control): 0.451086 | p-value: 0.045906
# Pearson Top 20 DEG (true vs. predicted): 0.840583 | p-value: 0.000003
# Evaluating double 124/130: ZC3HAV1+CEBPA
# MMD (true vs. control):     0.507293
# MMD (true vs. predicted):   0.976590
# MSE (true vs. control):     0.124327
# MSE (true vs. predicted):   0.086158
# KLD (true vs. control):     0.013248
# KLD (true vs. predicted):   0.007211
# Pearson Top 20 DEG (true vs. control): 0.145348 | p-value: 0.540920
# Pearson Top 20 DEG (true vs. predicted): 0.955372 | p-value: 0.000000
# Evaluating double 125/130: ETS2+IKZF3
# MMD (true vs. control):     0.428888
# MMD (true vs. predicted):   0.702512
# MSE (true vs. control):     0.087990
# MSE (true vs. predicted):   0.053541
# KLD (true vs. control):     0.010975
# KLD (true vs. predicted):   0.008683
# Pearson Top 20 DEG (true vs. control): 0.370469 | p-value: 0.107851
# Pearson Top 20 DEG (true vs. predicted): 0.866242 | p-value: 0.000001
# Evaluating double 126/130: CEBPB+PTPN12
# MMD (true vs. control):     0.314081
# MMD (true vs. predicted):   0.585183
# MSE (true vs. control):     0.077841
# MSE (true vs. predicted):   0.045880
# KLD (true vs. control):     0.001748
# KLD (true vs. predicted):   0.002482
# Pearson Top 20 DEG (true vs. control): 0.297266 | p-value: 0.203080
# Pearson Top 20 DEG (true vs. predicted): 0.678285 | p-value: 0.001012
# Evaluating double 127/130: IGDCC3+ZBTB25
# MMD (true vs. control):     0.394384
# MMD (true vs. predicted):   0.607104
# MSE (true vs. control):     0.083960
# MSE (true vs. predicted):   0.048898
# KLD (true vs. control):     0.005252
# KLD (true vs. predicted):   0.003518
# Pearson Top 20 DEG (true vs. control): 0.272205 | p-value: 0.245624
# Pearson Top 20 DEG (true vs. predicted): 0.916520 | p-value: 0.000000
# Evaluating double 128/130: MAP2K3+SLC38A2
# MMD (true vs. control):     0.296137
# MMD (true vs. predicted):   0.498100
# MSE (true vs. control):     0.069197
# MSE (true vs. predicted):   0.037744
# KLD (true vs. control):     0.001132
# KLD (true vs. predicted):   0.001821
# Pearson Top 20 DEG (true vs. control): 0.141487 | p-value: 0.551835
# Pearson Top 20 DEG (true vs. predicted): 0.837527 | p-value: 0.000004
# Evaluating double 129/130: CDKN1B+CDKN1A
# MMD (true vs. control):     0.371046
# MMD (true vs. predicted):   0.604317
# MSE (true vs. control):     0.079099
# MSE (true vs. predicted):   0.045504
# KLD (true vs. control):     0.003326
# KLD (true vs. predicted):   0.002521
# Pearson Top 20 DEG (true vs. control): 0.213503 | p-value: 0.366091
# Pearson Top 20 DEG (true vs. predicted): 0.928270 | p-value: 0.000000
# Evaluating double 130/130: DUSP9+KLF1
# MMD (true vs. control):     0.461285
# MMD (true vs. predicted):   0.700159
# MSE (true vs. control):     0.083030
# MSE (true vs. predicted):   0.049340
# KLD (true vs. control):     0.015988
# KLD (true vs. predicted):   0.008879
# Pearson Top 20 DEG (true vs. control): -0.155152 | p-value: 0.513656
# Pearson Top 20 DEG (true vs. predicted): 0.935398 | p-value: 0.000000

# %%
import pandas as pd
filepath = '../cris_test/results/demo_test/gears_norman_reduced_split_simulation_seed_42_hidden_size_64_double_metrics.csv'
results = pd.read_csv(filepath)

# %%
results
# Out:
#              double  mmd_true_vs_ctrl  mmd_true_vs_pred  mse_true_vs_ctrl  \
# 0     C3orf72+FOXL2          0.339430          0.623679          0.086623
# 1     ZBTB10+PTPN12          0.376876          0.703073          0.091089
# 2        SGK1+S1PR2          0.385643          0.638535          0.083990
# 3     RHOXF2+ZBTB25          0.410998          0.645421          0.085957
# 4       KLF1+TGFBR2          0.332317          0.551943          0.067557
# ..              ...               ...               ...               ...
# 125    CEBPB+PTPN12          0.314081          0.585183          0.077841
# 126   IGDCC3+ZBTB25          0.394384          0.607104          0.083960
# 127  MAP2K3+SLC38A2          0.296137          0.498100          0.069197
# 128   CDKN1B+CDKN1A          0.371046          0.604317          0.079099
# 129      DUSP9+KLF1          0.461285          0.700159          0.083030
#
#      mse_true_vs_pred  kld_true_vs_ctrl  kld_true_vs_pred  \
# 0            0.053890          0.002077          0.001739
# 1            0.058669          0.003361          0.003322
# 2            0.050543          0.004669          0.003529
# 3            0.050997          0.006405          0.003855
# 4            0.036747          0.003217          0.003444
# ..                ...               ...               ...
# 125          0.045880          0.001748          0.002482
# 126          0.048898          0.005252          0.003518
# 127          0.037744          0.001132          0.001821
# 128          0.045504          0.003326          0.002521
# 129          0.049340          0.015988          0.008879
#
#      pearsonTop20_true_vs_ctrl  pearson_pval_true_vs_ctrl  \
# 0                    -0.066646                   0.780115
# 1                    -0.133943                   0.573443
# 2                     0.367951                   0.110454
# 3                     0.215142                   0.362335
# 4                    -0.250833                   0.286107
# ..                         ...                        ...
# 125                   0.297266                   0.203080
# 126                   0.272205                   0.245624
# 127                   0.141487                   0.551835
# 128                   0.213503                   0.366091
# 129                  -0.155152                   0.513656
#
#      pearsonTop20_true_vs_pred  pearson_pval_true_vs_pred
# 0                     0.750948               1.358936e-04
# 1                     0.854320               1.633744e-06
# 2                     0.710611               4.456751e-04
# 3                     0.920853               8.662332e-09
# 4                     0.771662               6.756299e-05
# ..                         ...                        ...
# 125                   0.678285               1.011904e-03
# 126                   0.916520               1.376997e-08
# 127                   0.837527               4.088613e-06
# 128                   0.928270               3.672547e-09
# 129                   0.935398               1.470195e-09
#
# [130 rows x 11 columns]
